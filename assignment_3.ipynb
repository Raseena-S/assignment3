# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statistics as stat
import seaborn as sns 
# %matplotlib inline
import statistics

# %%
data=pd.read_csv('StudentsPerformance.csv')
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# 1.no of males and females

# %%
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# 2.analysis of parental level of education

# %%
data1=data.set_index('parental level of education')
data1
# Out:
#                              gender race/ethnicity         lunch  \
# parental level of education
# some high school             female        group C  free/reduced
# high school                  female        group B  free/reduced
# some high school             female        group B  free/reduced
# some college                 female        group B      standard
# some college                 female        group C  free/reduced
# ...                             ...            ...           ...
# some college                   male        group E      standard
# some college                   male        group A      standard
# some college                   male        group D      standard
# associate's degree             male        group E  free/reduced
# bachelor's degree              male        group E      standard
#
#                             test preparation course  math score  \
# parental level of education
# ...

# %%
plt.hist(data['parental level of education'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# 3.max average on math score ,reading and writing skill

# %%
data['average']=data['math score']+data['writing score']+data['reading score']/3
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  total  \
# ...

# %%
data['average'].max()
# Out:
# 233.33333333333334

# %% [markdown]
# 4.scoring variation for math ,reading and writing skill

# %%
plt.hist(data['total'])
plt.hist(data['gender'])
plt.hist(data['parental level of education'])
plt.show()

# %%
data1=data.set_index('gender')
data1
# Out:
#        race/ethnicity parental level of education         lunch  \
# gender
# female        group C            some high school  free/reduced
# female        group B                 high school  free/reduced
# female        group B            some high school  free/reduced
# female        group B                some college      standard
# female        group C                some college  free/reduced
# ...               ...                         ...           ...
# male          group E                some college      standard
# male          group A                some college      standard
# male          group D                some college      standard
# male          group E          associate's degree  free/reduced
# male          group E           bachelor's degree      standard
#
#        test preparation course  math score  reading score  writing score  \
# gender
# female                    none           0             17             10
# ...

# %%
plt.hist(data1['math score'])
plt.hist(data1['writing score'])
plt.hist(data1['reading score'])
# Out:
# (array([  4.,   8.,  25.,  61., 137., 180., 237., 171., 120.,  57.]),
#  array([ 17. ,  25.3,  33.6,  41.9,  50.2,  58.5,  66.8,  75.1,  83.4,
#          91.7, 100. ]),
#  <a list of 10 Patch objects>)

# %%
data2=data.set_index('test preparation course')
data2
# Out:
#                          gender race/ethnicity parental level of education  \
# test preparation course
# none                     female        group C            some high school
# none                     female        group B                 high school
# none                     female        group B            some high school
# none                     female        group B                some college
# none                     female        group C                some college
# ...                         ...            ...                         ...
# completed                  male        group E                some college
# completed                  male        group A                some college
# completed                  male        group D                some college
# completed                  male        group E          associate's degree
# completed                  male        group E           bachelor's degree
#
# ...

# %%
plt.hist(data2['math score'])
plt.hist(data2['reading score'])
plt.hist(data2['writing score'])
plt.show()

# %% [markdown]
# 5.top math students to get bonus points

# %%
data.sort_values('math score',ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999    male        group E           bachelor's degree      standard
# 996    male        group A                some college      standard
# 515  female        group E                some college      standard
# 517  female        group E          associate's degree      standard
# 516  female        group E           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 2    female        group B            some high school  free/reduced
# 51   female        group C            some high school  free/reduced
# 3    female        group B                some college      standard
# 1    female        group B                 high school  free/reduced
# 0    female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  total
# ...
